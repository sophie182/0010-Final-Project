# %% [markdown]
# # Work

# %%
import pandas as pd

# read in file
rates = pd.read_csv("meter_rates.csv", index_col='_id')

# find all zone names
print(rates['zone'].unique())
# Out:
# ['301 - Sheridan Harvard Lot' '302 - Sheridan Kirkwood Lot'
#  '304 - Tamello Beatty Lot' '307 - Eva Beatty Lot'
#  '311 - Ansley Beatty Lot' '314 - Penn Circle NW Lot'
#  '321 - Beacon Bartlett Lot' '322 - Forbes Shady Lot'
#  '323 - Douglas Phillips Lot' '324 - Forbes Murray Lot'
#  '325 - JCC/Forbes Lot' '328 - Ivy Bellefonte Lot'
#  '331 - Homewood Zenith Lot' '334 - Taylor Street Lot'
#  '335 - Friendship Cedarville Lot' '337 - 52nd & Butler Lot'
#  '338 - 42nd & Butler Lot' '341 - 18th & Sidney Lot'
#  '342 - East Carson Lot' '343 - 19th & Carson Lot'
#  '344 - 18th & Carson Lot' '345 - 20th & Sidney Lot'
#  '351 - Brownsville & Sandkey Lot' '354 - Walter/Warrington Lot'
#  '355 - Asteroid Warrington Lot' '357 - Shiloh Street Lot'
#  '361 - Brookline Lot' '363 - Beechview Lot' '369 - Main/Alexander Lot'
#  '371 - East Ohio Street Lot' '375 - Oberservatory Hill Lot'
#  '401 - Downtown 1' '402 - Downtown 2' '403 - Uptown'
#  '404 - Strip Disctrict' '405 - Lawrenceville'
# ...

# %%
# getting shadyside zones
shadyside_keywords = ["ivy bellefonte lot", "shadyside", "mellon park",]

shadyside_filter = rates['zone'].str.contains('|'.join(shadyside_keywords), case=False)
shadyside = rates[shadyside_filter]

# removing duplicates
shadyside2 = shadyside.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(shadyside2)) + " zones in Shadyside.")
print(shadyside2)

# finding relevant information about meters in shadyside
print("\n" + "The average rate of meters in Shadyside is " + str(round(shadyside2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Shadyside is " + str(shadyside2['meters'].sum()) + ".")
# Out:
# There are 5 zones in Shadyside.
#                          zone       as_of  spaces  rate  \
# _id
# 68   328 - Ivy Bellefonte Lot  2018-01-19      74   2.0
# 101         414 - Mellon Park  2018-01-19      76   1.0
# 148           411 - Shadyside  2017-11-15     345   1.5
# 149                SHADYSIDE1  2017-11-15      65   NaN
# 150                SHADYSIDE2  2017-11-15     280   1.5
#
#            rate_description  meters        type
# _id
# 68                 $2.00/HR     5.0  off-street
# 101                $1.00/HR     4.0   on-street
# 148                $1.50/HR    52.0   on-street
# 149  $1.50($2 after 2pm)/HR    52.0   on-street
# 150                $1.50/HR    52.0   on-street
#
# The average rate of meters in Shadyside is 1.5 dollars per hour.
# The total amount of meters in Shadyside is 165.0.

# %%
# getting oakland zones
oakland_keywords = ["oakland", "technology drive", "s. craig"]

oakland_filter = rates['zone'].str.contains('|'.join(oakland_keywords), case=False)
oakland = rates[oakland_filter]

# removing duplicates
oakland2 = oakland.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(oakland2)) + " zones in Oakland.")
print(oakland2)

# finding relevant information about meters in oakland
print("\n" + "The average rate of meters in Oakland is " + str(round(oakland2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Oakland is " + str(oakland2['meters'].sum()) + ".")
# Out:
# There are 6 zones in Oakland.
#                        zone       as_of  spaces  rate        rate_description  \
# _id
# 94          407 - Oakland 1  2018-01-19     227   3.0                $3.00/HR
# 95          408 - Oakland 2  2018-01-19     301   3.0                $3.00/HR
# 96          409 - Oakland 3  2018-01-19     476   3.0                $3.00/HR
# 97          410 - Oakland 4  2018-01-19     572   3.0                $3.00/HR
# 111  424 - Technology Drive  2018-01-19      48   NaN                *SPECIAL
# 147                S. Craig  2017-09-08      37   NaN  $3($2.50 after 2pm)/HR
#
#      meters       type
# _id
# 94     30.0  on-street
# 95     38.0  on-street
# 96     60.0  on-street
# 97     45.0  on-street
# 111     5.0  on-street
# 147     6.0  on-street
#
# The average rate of meters in Oakland is 3.0 dollars per hour.
# The total amount of meters in Oakland is 184.0.

# %%
# getting east liberty zones
east_liberty_keywords = ["sheridan", "beatty", "penn circle", "east liberty", ]

east_liberty_filter = rates['zone'].str.contains('|'.join(east_liberty_keywords), case=False)
eastLiberty = rates[east_liberty_filter]

# removing duplicates
eastLiberty2 = eastLiberty.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(eastLiberty2)) + " zones in East Liberty.")
print(eastLiberty2)

# finding relevant information about meters in east liberty
print("\n" + "The average rate of meters in East Liberty is " + str(round(eastLiberty2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in East Liberty is " + str(eastLiberty2['meters'].sum()) + ".")
# Out:
# There are 7 zones in East Liberty.
#                             zone       as_of  spaces  rate rate_description  \
# _id
# 57    301 - Sheridan Harvard Lot  2018-01-19      41   1.0         $1.00/HR
# 58   302 - Sheridan Kirkwood Lot  2018-01-19     114   1.0         $1.00/HR
# 59      304 - Tamello Beatty Lot  2018-01-19      76   1.0         $1.00/HR
# 60          307 - Eva Beatty Lot  2018-01-19     130   1.0         $1.00/HR
# 61       311 - Ansley Beatty Lot  2018-01-19      23   1.0         $1.00/HR
# 62      314 - Penn Circle NW Lot  2018-01-19     125   1.0         $1.00/HR
# 99            412 - East Liberty  2018-01-19     483   1.5         $1.50/HR
#
#      meters        type
# _id
# 57      2.0  off-street
# 58      3.0  off-street
# 59      2.0  off-street
# 60      2.0  off-street
# 61      1.0  off-street
# 62      2.0  off-street
# 99     57.0   on-street
#
# The average rate of meters in East Liberty is 1.07 dollars per hour.
# ...

# %%
# getting squirrel hill zones
sq_hill_keywords = ["forbes", "beacon", "douglas", "sq.hill", "squirrel"]

sq_hill_filter = rates['zone'].str.contains('|'.join(sq_hill_keywords), case=False)
sqHill = rates[sq_hill_filter]

# removing duplicates
sqHill2 = sqHill.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(sqHill2)) + " zones in Squirrel Hill.")
print(sqHill2)

# finding relevant information about meters in squirrel hill
print("\n" + "The average rate of meters in Squirrel Hill is " + str(round(sqHill2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Squirrel Hill is " + str(sqHill2['meters'].sum()) + ".")
# Out:
# There are 8 zones in Squirrel Hill.
#                            zone       as_of  spaces  rate rate_description  \
# _id
# 63    321 - Beacon Bartlett Lot  2018-01-19      69   1.0         $1.00/HR
# 64       322 - Forbes Shady Lot  2018-01-19      59   1.0         $1.00/HR
# 65   323 - Douglas Phillips Lot  2018-01-19      45   1.0         $1.00/HR
# 66      324 - Forbes Murray Lot  2018-01-19      72   1.0         $1.00/HR
# 67         325 - JCC/Forbes Lot  2018-01-19      69   1.0         $1.00/HR
# 100         413 - Squirrel Hill  2018-01-19     354   1.5         $1.50/HR
# 214                    SQ.HILL1  2017-11-13     296   1.5         $1.50/HR
# 215                    SQ.HILL2  2017-11-13      80   1.5         $1.50/HR
#
#      meters        type
# _id
# 63      3.0  off-street
# 64      3.0  off-street
# 65      2.0  off-street
# 66      3.0  off-street
# 67      2.0  off-street
# 100    55.0   on-street
# 214     NaN   on-street
# 215     NaN   on-street
#
# ...

# %%
# getting homewood zones
homewood_keywords_filter = rates['zone'].str.contains("homewood", case=False)
homewood = rates[homewood_keywords_filter]

# removing duplicates
homewood2 = homewood.drop_duplicates(subset='zone', keep='last')
print("There is " + str(len(homewood2)) + " zone in Homewood.")
print(homewood2)

# finding relevant information about meters in homewood
print("\n" + "The average rate of meters in Homewood is " + str(round(homewood2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Homewood is " + str(homewood2['meters'].sum()) + ".")
# Out:
# There are 1 zones in Homewood.
#                           zone       as_of  spaces  rate rate_description  \
# _id
# 69   331 - Homewood Zenith Lot  2018-01-19      24   1.0         $1.00/HR
#
#      meters        type
# _id
# 69      1.0  off-street
#
# The average rate of meters in Homewood is 1.0 dollars per hour.
# The total amount of meters in Homewood is 1.0.

# %%
# getting bloomfield zones
bloomfield_keywords = ["taylor street lot", "friendship cedarville", "bloomfield"]

bloomfield_keywords_filter = rates['zone'].str.contains('|'.join(bloomfield_keywords), case=False)
bloomfield = rates[bloomfield_keywords_filter]

# removing duplicates
bloomfield2 = bloomfield.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(bloomfield2)) + " zones in Bloomfield.")
print(bloomfield2)

# finding relevant information about meters in bloomfield
print("\n" + "The average rate of meters in Bloomfield is " + str(round(bloomfield2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Bloomfield is " + str(bloomfield2['meters'].sum()) + ".")
# Out:
# There are 3 zones in Bloomfield.
#                                 zone       as_of  spaces  rate  \
# _id
# 70           334 - Taylor Street Lot  2018-01-19      26   1.0
# 71   335 - Friendship Cedarville Lot  2018-01-19      80   1.0
# 93      406 - Bloomfield (On-street)  2018-01-19     489   1.0
#
#     rate_description  meters        type
# _id
# 70          $1.00/HR     1.0  off-street
# 71          $1.00/HR     2.0  off-street
# 93          $1.00/HR    71.0   on-street
#
# The average rate of meters in Bloomfield is 1.0 dollars per hour.
# The total amount of meters in Bloomfield is 74.0.

# %%
# getting Lawrenceville zones
lawrenceville_keywords = ["butler", "lawrenceville"]

lawrenceville_keywords_filter = rates['zone'].str.contains('|'.join(lawrenceville_keywords), case=False)
lawrenceville = rates[lawrenceville_keywords_filter]

# removing duplicates
lawrenceville2 = lawrenceville.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(lawrenceville2)) + " zones in Lawrenceville.")
print(lawrenceville2)

# finding relevant information about meters in carrick
print("\n" + "The average rate of meters in Lawrenceville is " + str(round(lawrenceville2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Lawrenceville is " + str(lawrenceville2['meters'].sum()) + ".")
# Out:
# There are 3 zones in Lawrenceville.
#                         zone       as_of  spaces  rate rate_description  \
# _id
# 72   337 - 52nd & Butler Lot  2018-01-19      12   1.0         $1.00/HR
# 73   338 - 42nd & Butler Lot  2018-01-19      22   1.0         $1.00/HR
# 92       405 - Lawrenceville  2018-01-19     187   1.0         $1.00/HR
#
#      meters        type
# _id
# 72      1.0  off-street
# 73      1.0  off-street
# 92     29.0   on-street
#
# The average rate of meters in Lawrenceville is 1.0 dollars per hour.
# The total amount of meters in Lawrenceville is 31.0.

# %%
# getting southside flats zones
southside_flats_keywords = ["carson", "sidney", "ss & ssw", "southside"]

southside_flats_keywords_filter = rates['zone'].str.contains('|'.join(southside_flats_keywords), case=False)
southsideFlats = rates[southside_flats_keywords_filter]

# removing duplicates
southsideFlats2 = southsideFlats.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(southsideFlats2)) + " zones in Southside Flats.")
print(southsideFlats2)

# finding relevant information about meters in carrick
print("\n" + "The average rate of meters in Southside Flats is " + str(round(southsideFlats2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Southside Flats is " + str(southsideFlats2['meters'].sum()) + ".")
# Out:
# There are 7 zones in Southside Flats.
#                         zone       as_of  spaces  rate rate_description  \
# _id
# 74   341 - 18th & Sidney Lot  2018-01-19      45   1.0         $1.00/HR
# 75     342 - East Carson Lot  2018-01-19      35   1.0         $1.00/HR
# 76   343 - 19th & Carson Lot  2018-01-19      27   1.0         $1.00/HR
# 77   344 - 18th & Carson Lot  2018-01-19      41   1.0         $1.00/HR
# 78   345 - 20th & Sidney Lot  2018-01-19      80   1.0         $1.00/HR
# 102           415 - SS & SSW  2018-01-19     707   1.5         $1.50/HR
# 218           Southside Lots  2018-01-19     228   1.0         $1.00/HR
#
#      meters        type
# _id
# 74      2.0  off-street
# 75      2.0  off-street
# 76      1.0  off-street
# 77      2.0  off-street
# 78      2.0  off-street
# 102   101.0   on-street
# 218     NaN  off-street
#
# The average rate of meters in Southside Flats is 1.07 dollars per hour.
# The total amount of meters in Southside Flats is 110.0.

# %%
# getting carrick zones
carrick_keywords = ["carrick", "brownsville & sandkey"]

carrick_keywords_filter = rates['zone'].str.contains('|'.join(carrick_keywords), case=False)
carrick = rates[carrick_keywords_filter]

# removing duplicates
carrick2 = carrick.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(carrick2)) + " zones in Carrick.")
print(carrick2)

# finding relevant information about meters in carrick
print("\n" + "The average rate of meters in Carrick is " + str(round(carrick2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Carrick is " + str(carrick2['meters'].sum()) + ".")
# Out:
# There are 2 zones in Carrick.
#                                 zone       as_of  spaces  rate  \
# _id
# 79   351 - Brownsville & Sandkey Lot  2018-01-19      80   1.0
# 103                    416 - Carrick  2018-01-19      65   0.5
#
#     rate_description  meters        type
# _id
# 79          $1.00/HR     2.0  off-street
# 103         $0.50/HR     9.0   on-street
#
# The average rate of meters in Carrick is 0.75 dollars per hour.
# The total amount of meters in Carrick is 11.0.

# %%
# getting allentown zones
allentown_keywords = ["warrington", "allentown"]

allentown_keywords_filter = rates['zone'].str.contains('|'.join(allentown_keywords), case=False)
allentown = rates[allentown_keywords_filter]

# removing duplicates
allentown2 = allentown.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(allentown2)) + " zones in Allentown.")
print(allentown2)

# finding relevant information about meters in allentown
print("\n" + "The average rate of meters in Allentownis " + str(round(allentown2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Allentown is " + str(allentown2['meters'].sum()) + ".")
# Out:
# There are 3 zones in Allentown.
#                               zone       as_of  spaces  rate rate_description  \
# _id
# 80     354 - Walter/Warrington Lot  2018-01-19      15   1.0         $1.00/HR
# 81   355 - Asteroid Warrington Lot  2018-01-19      13   1.0         $1.00/HR
# 104                417 - Allentown  2018-01-19      23   0.5         $0.50/HR
#
#      meters        type
# _id
# 80      1.0  off-street
# 81      1.0  off-street
# 104     3.0   on-street
#
# The average rate of meters in Allentownis 0.83 dollars per hour.
# The total amount of meters in Allentown is 5.0.

# %%
# getting mount washington zones
mount_washington_keywords = ["washington", "shiloh street"]

mount_washington_keywords_filter = rates['zone'].str.contains('|'.join(mount_washington_keywords), case=False)
mtWashington = rates[mount_washington_keywords_filter]

# removing duplicates
mtWashington2 = mtWashington.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(mtWashington2)) + " zones in Mount Washington.")
print(mtWashington2)

# finding relevant information about meters in mount washington
print("\n" + "The average rate of meters in Mount Washington is " + str(round(mtWashington2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Mount Washington is " + str(mtWashington2['meters'].sum()) + ".")
# Out:
# There are 2 zones in Mount Washington.
#                         zone       as_of  spaces  rate rate_description  \
# _id
# 82   357 - Shiloh Street Lot  2018-01-19      73   1.0         $1.00/HR
# 107     420 - Mt. Washington  2018-01-19      98   1.0         $1.00/HR
#
#      meters        type
# _id
# 82      3.0  off-street
# 107    17.0   on-street
#
# The average rate of meters in Mount Washington is 1.0 dollars per hour.
# The total amount of meters in Mount Washington is 20.0.

# %%
# getting brookline zones
brookline_keywords_filter = rates['zone'].str.contains("brookline", case=False)
brookline = rates[brookline_keywords_filter]

# removing duplicates
brookline2 = brookline.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(brookline2)) + " zones in Brookline.")
print(brookline2)

# finding relevant information about meters in brookline
print("\n" + "The average rate of meters in Brookline is " + str(round(brookline2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Brookline is " + str(brookline2['meters'].sum()) + ".")
# Out:
# There is 2 zone in Brookline .
#                     zone       as_of  spaces  rate rate_description  meters  \
# _id
# 83   361 - Brookline Lot  2018-01-19      47   1.0         $1.00/HR     1.0
# 106      419 - Brookline  2018-01-19     201   1.0         $1.00/HR    21.0
#
#            type
# _id
# 83   off-street
# 106   on-street
#
# The average rate of meters in Brookline is 1.0 dollars per hour.
# The total amount of meters in Brookline is 22.0.

# %%
# getting beechview zones
beechview_keywords_filter = rates['zone'].str.contains("beechview", case=False)
beechview = rates[beechview_keywords_filter]

# removing duplicates
beechview2 = beechview.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(beechview2)) + " zones in Beechview.")
print(beechview2)

# finding relevant information about meters in beechview
print("\n" + "The average rate of meters in Beechview is " + str(round(beechview2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Beechview is " + str(beechview2['meters'].sum()) + ".")
# Out:
# There are 2 zones in Beechview.
#                     zone       as_of  spaces  rate rate_description  meters  \
# _id
# 84   363 - Beechview Lot  2018-01-19      17   1.0         $1.00/HR     1.0
# 105      418 - Beechview  2018-01-19      78   1.0         $1.00/HR     8.0
#
#            type
# _id
# 84   off-street
# 105   on-street
#
# The average rate of meters in Beechview is 1.0 dollars per hour.
# The total amount of meters in Beechview is 9.0.

# %%
# getting west end zones
west_end_keywords = ["main/alexander", "west end"]

west_end_keywords_filter = rates['zone'].str.contains('|'.join(west_end_keywords), case=False)
westEnd = rates[west_end_keywords_filter]

# removing duplicates
westEnd2 = westEnd.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(westEnd2)) + " zones in West End.")
print(westEnd2)

# finding relevant information about meters in westEnd
print("\n" + "The average rate of meters in West End is " + str(round(westEnd2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in West End is " + str(westEnd2['meters'].sum()) + ".")
# Out:
# There are 2 zones in West End.
#                          zone       as_of  spaces  rate rate_description  \
# _id
# 85   369 - Main/Alexander Lot  2018-01-19      29   1.0         $1.00/HR
# 110            423 - West End  2018-01-19      52   1.0         $1.00/HR
#
#      meters        type
# _id
# 85      1.0  off-street
# 110     6.0   on-street
#
# The average rate of meters in West End is 1.0 dollars per hour.
# The total amount of meters in West End is 7.0.

# %%
# getting East Allegheny zones
east_allegheny_keywords_filter = rates['zone'].str.contains("east ohio street lot", case=False)
eastAllegheny = rates[east_allegheny_keywords_filter]

# removing duplicates
eastAllegheny2 = eastAllegheny.drop_duplicates(subset='zone', keep='last')
print("There is " + str(len(eastAllegheny2)) + " zone in East Allegheny.")
print(eastAllegheny2)

# finding relevant information about meters in East Allegheny
print("\n" + "The average rate of meters in East Allegheny is " + str(round(eastAllegheny2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in East Allegheny is " + str(eastAllegheny2['meters'].sum()) + ".")
# Out:
# There is 1 zone in East Allegheny.
#                            zone       as_of  spaces  rate rate_description  \
# _id
# 86   371 - East Ohio Street Lot  2018-01-19      88   1.0         $1.00/HR
#
#      meters        type
# _id
# 86      3.0  off-street
#
# The average rate of meters in East Allegheny is 1.0 dollars per hour.
# The total amount of meters in East Allegheny is 3.0.

# %%
# getting Perry North zones
perry_north_keywords_filter = rates['zone'].str.contains("oberservatory hill lot", case=False)
perryNorth = rates[perry_north_keywords_filter]

# removing duplicates
perryNorth2 = perryNorth.drop_duplicates(subset='zone', keep='last')
print("There is " + str(len(perryNorth2)) + " zone in Perry North.")
print(perryNorth2)

# finding relevant information about meters in Perry North
print("\n" + "The average rate of meters in Perry North is " + str(round(perryNorth2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Perry North is " + str(perryNorth2['meters'].sum()) + ".")
# Out:
# There is 1 zone in Perry North.
#                              zone       as_of  spaces  rate rate_description  \
# _id
# 87   375 - Oberservatory Hill Lot  2018-01-19      23   1.0         $1.00/HR
#
#      meters        type
# _id
# 87      1.0  off-street
#
# The average rate of meters in Perry North is 1.0 dollars per hour.
# The total amount of meters in Perry North is 1.0.

# %%
# getting downtown zones
downtown_keywords_filter = rates['zone'].str.contains("downtown", case=False)
downtown = rates[downtown_keywords_filter]

# removing duplicates
downtown2 = downtown.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(downtown2)) + " zones in Downtown.")
print(downtown2)

# finding relevant information about meters in downtown
print("\n" + "The average rate of meters in Downtown is " + str(round(downtown2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Downtown is " + str(downtown2['meters'].sum()) + ".")
# Out:
# There are 2 zones in Downtown.
#                  zone       as_of  spaces  rate rate_description  meters  \
# _id
# 88   401 - Downtown 1  2018-01-19     299   4.0         $4.00/HR    42.0
# 89   402 - Downtown 2  2018-01-19     373   4.0         $4.00/HR    59.0
#
#           type
# _id
# 88   on-street
# 89   on-street
#
# The average rate of meters in Downtown is 4.0 dollars per hour.
# The total amount of meters in Downtown is 101.0.

# %%
# getting uptown zones
uptown_keywords_filter = rates['zone'].str.contains("uptown", case=False)
uptown = rates[uptown_keywords_filter]

# removing duplicates
uptown2 = uptown.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(uptown2)) + " zones in Uptown.")
print(uptown2)

# finding relevant information about meters in uptown
print("\n" + "The average rate of meters in Uptown is " + str(round(uptown2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Uptown is " + str(uptown2['meters'].sum()) + ".")
# Out:
# There are 3 zones in Uptown.
#              zone       as_of  spaces  rate rate_description  meters  \
# _id
# 90   403 - Uptown  2018-01-19     690   1.5         $1.50/HR    70.0
# 216       UPTOWN1  2017-11-28     261   1.5         $1.50/HR     NaN
# 217       UPTOWN2  2017-11-28     360   1.5         $1.50/HR     NaN
#
#           type
# _id
# 90   on-street
# 216  on-street
# 217  on-street
#
# The average rate of meters in Uptown is 1.5 dollars per hour.
# The total amount of meters in Uptown is 70.0.

# %%
# getting strip district zones
strip_district_keywords_filter = rates['zone'].str.contains("Strip Disctrict", case=False)
stripDist = rates[strip_district_keywords_filter]

# removing duplicates
stripDist2 = stripDist.drop_duplicates(subset='zone', keep='last')
print("There is " + str(len(stripDist2)) + " zone in Strip District.")
print(stripDist2)

# finding relevant information about meters in strip district
print("\n" + "The average rate of meters in Strip District is " + str(round(stripDist2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Strip District is " + str(stripDist2['meters'].sum()) + ".")
# Out:
# There is 1 zone in Strip District.
#                       zone       as_of  spaces  rate rate_description  meters  \
# _id
# 91   404 - Strip Disctrict  2018-01-19     428   1.5         $1.50/HR    58.0
#
#           type
# _id
# 91   on-street
#
# The average rate of meters in Strip District is 1.5 dollars per hour.
# The total amount of meters in Strip District is 58.0.

# %%
# getting North Shore zones
north_shore_keywords = ["northside", "northshore"]

north_shore_keywords_filter = rates['zone'].str.contains('|'.join(north_shore_keywords), case=False)
northShore = rates[north_shore_keywords_filter]

# removing duplicates
northShore2 = northShore.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(northShore2)) + " zones in North Shore.")
print(northShore2)

# finding relevant information about meters in north shore
print("\n" + "The average rate of meters in North Shore is " + str(round(northShore2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in North Shore is " + str(northShore2['meters'].sum()) + ".")
# Out:
# There are 2 zones in North Shore.
#                  zone       as_of  spaces  rate rate_description  meters  \
# _id
# 108   421 - NorthSide  2018-01-19     757   1.0         $1.00/HR    92.0
# 109  422 - Northshore  2018-01-19     237   3.0         $3.00/HR    30.0
#
#           type
# _id
# 108  on-street
# 109  on-street
#
# The average rate of meters in North Shore is 2.0 dollars per hour.
# The total amount of meters in North Shore is 122.0.

# %%
# getting Larimer zones
larimer_keywords_filter = rates['zone'].str.contains("bakery sq", case=False)
larimer = rates[larimer_keywords_filter]

# removing duplicates
larimer2 = larimer.drop_duplicates(subset='zone', keep='last')
print("There is " + str(len(larimer2)) + " zone in Larimer.")
print(larimer2)

# finding relevant information about meters in Larimer
print("\n" + "The average rate of meters in Larimer is " + str(round(larimer2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Larimer is " + str(larimer2['meters'].sum()) + ".")
# Out:
# There is 1 zone in Larimer.
#                 zone       as_of  spaces  rate rate_description  meters  \
# _id
# 112  425 - Bakery Sq  2018-01-19      45   2.0         $2.00/HR     4.0
#
#           type
# _id
# 112  on-street
#
# The average rate of meters in Larimer is 2.0 dollars per hour.
# The total amount of meters in Larimer is 4.0.

# %%
# getting hill district zones
hill_district_keywords = ["HILL-DIST-2", "Hill District"]

hill_district_keywords_filter = rates['zone'].str.contains('|'.join(hill_district_keywords), case=False)
hillDist = rates[hill_district_keywords_filter]

# removing duplicates
hillDist2 = hillDist.drop_duplicates(subset='zone', keep='last')
print("There are " + str(len(hillDist2)) + " zones in Hill District.")
print(hillDist2)

# finding relevant information about meters in hill district
print("\n" + "The average rate of meters in Hill District is " + str(round(hillDist2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Hill District is " + str(hillDist2['meters'].sum()) + ".")
# Out:
# There are 2 zones in Hill District.
#                     zone       as_of  spaces  rate rate_description  meters  \
# _id
# 113  426 - Hill District  2018-01-19      26   1.0         $1.00/HR     4.0
# 114          HILL-DIST-2  2017-11-28     152   1.5         $1.50/HR     8.0
#
#           type
# _id
# 113  on-street
# 114  on-street
#
# The average rate of meters in Hill District is 1.25 dollars per hour.
# The total amount of meters in Hill District is 12.0.

# %%
# getting monroe heights zones
monroe_heights_keywords_filter = rates['zone'].str.contains("w circ dr", case=False)
monroeHeights = rates[monroe_heights_keywords_filter]

# removing duplicates
monroeHeights2 = monroeHeights.drop_duplicates(subset='zone', keep='last')
print("There is " + str(len(monroeHeights2)) + " zone in Monroe Heights.")
print(monroeHeights2)

# finding relevant information about meters in Monroe Heights
print("\n" + "The average rate of meters in Monroe Heights is " + str(round(monroeHeights2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Monroe Heights is " + str(monroeHeights2['meters'].sum()) + ".")
# Out:
# There is 1 zone in Monroe Heights.
#           zone       as_of  spaces  rate rate_description  meters       type
# _id
# 180  W CIRC DR  2017-09-13      95   1.0            $1/HR     1.0  on-street
#
# The average rate of meters in Monroe Heights is 1.0 dollars per hour.
# The total amount of meters in Monroe Heights is 1.0.

# %% [markdown]
# # Conclusions

# %%
# getting shadyside zones
shadyside_keywords = ["ivy bellefonte lot", "shadyside", "mellon park",]

shadyside_filter = rates['zone'].str.contains('|'.join(shadyside_keywords), case=False)
shadyside = rates[shadyside_filter]

# removing duplicates
shadyside2 = shadyside.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(shadyside2)) + " zones in Shadyside.")
print("The average rate of meters in Shadyside is " + str(round(shadyside2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Shadyside is " + str(shadyside2['meters'].sum()) + ".")



# getting oakland zones
oakland_keywords = ["oakland", "technology drive", "s. craig"]

oakland_filter = rates['zone'].str.contains('|'.join(oakland_keywords), case=False)
oakland = rates[oakland_filter]

# removing duplicates
oakland2 = oakland.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(oakland2)) + " zones in Oakland.")
print("The average rate of meters in Oakland is " + str(round(oakland2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Oakland is " + str(oakland2['meters'].sum()) + ".")



# getting east liberty zones
east_liberty_keywords = ["sheridan", "beatty", "penn circle", "east liberty", ]

east_liberty_filter = rates['zone'].str.contains('|'.join(east_liberty_keywords), case=False)
eastLiberty = rates[east_liberty_filter]

# removing duplicates
eastLiberty2 = eastLiberty.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(eastLiberty2)) + " zones in East Liberty.")
print("The average rate of meters in East Liberty is " + str(round(eastLiberty2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in East Liberty is " + str(eastLiberty2['meters'].sum()) + ".")



# getting squirrel hill zones
sq_hill_keywords = ["forbes", "beacon", "douglas", "sq.hill", "squirrel"]

sq_hill_filter = rates['zone'].str.contains('|'.join(sq_hill_keywords), case=False)
sqHill = rates[sq_hill_filter]

# removing duplicates
sqHill2 = sqHill.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(sqHill2)) + " zones in Squirrel Hill.")
print("The average rate of meters in Squirrel Hill is " + str(round(sqHill2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Squirrel Hill is " + str(sqHill2['meters'].sum()) + ".")



# getting homewood zones
homewood_keywords_filter = rates['zone'].str.contains("homewood", case=False)
homewood = rates[homewood_keywords_filter]

# removing duplicates
homewood2 = homewood.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There is " + str(len(homewood2)) + " zone in Homewood.")
print("The average rate of meters in Homewood is " + str(round(homewood2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Homewood is " + str(homewood2['meters'].sum()) + ".")



# getting bloomfield zones
bloomfield_keywords = ["taylor street lot", "friendship cedarville", "bloomfield"]

bloomfield_keywords_filter = rates['zone'].str.contains('|'.join(bloomfield_keywords), case=False)
bloomfield = rates[bloomfield_keywords_filter]

# removing duplicates
bloomfield2 = bloomfield.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(bloomfield2)) + " zones in Bloomfield.")
print("The average rate of meters in Bloomfield is " + str(round(bloomfield2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Bloomfield is " + str(bloomfield2['meters'].sum()) + ".")



# getting Lawrenceville zones
lawrenceville_keywords = ["butler", "lawrenceville"]

lawrenceville_keywords_filter = rates['zone'].str.contains('|'.join(lawrenceville_keywords), case=False)
lawrenceville = rates[lawrenceville_keywords_filter]

# removing duplicates
lawrenceville2 = lawrenceville.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(lawrenceville2)) + " zones in Lawrenceville.")
print("The average rate of meters in Lawrenceville is " + str(round(lawrenceville2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Lawrenceville is " + str(lawrenceville2['meters'].sum()) + ".")



# getting southside flats zones
southside_flats_keywords = ["carson", "sidney", "ss & ssw", "southside"]

southside_flats_keywords_filter = rates['zone'].str.contains('|'.join(southside_flats_keywords), case=False)
southsideFlats = rates[southside_flats_keywords_filter]

# removing duplicates
southsideFlats2 = southsideFlats.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(southsideFlats2)) + " zones in Southside Flats.")
print("The average rate of meters in Southside Flats is " + str(round(southsideFlats2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Southside Flats is " + str(southsideFlats2['meters'].sum()) + ".")



# getting carrick zones
carrick_keywords = ["carrick", "brownsville & sandkey"]

carrick_keywords_filter = rates['zone'].str.contains('|'.join(carrick_keywords), case=False)
carrick = rates[carrick_keywords_filter]

# removing duplicates
carrick2 = carrick.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(carrick2)) + " zones in Carrick.")
print("The average rate of meters in Carrick is " + str(round(carrick2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Carrick is " + str(carrick2['meters'].sum()) + ".")



# getting allentown zones
allentown_keywords = ["warrington", "allentown"]

allentown_keywords_filter = rates['zone'].str.contains('|'.join(allentown_keywords), case=False)
allentown = rates[allentown_keywords_filter]

# removing duplicates
allentown2 = allentown.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(allentown2)) + " zones in Allentown.")
print("The average rate of meters in Allentownis " + str(round(allentown2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Allentown is " + str(allentown2['meters'].sum()) + ".")



# getting mount washington zones
mount_washington_keywords = ["washington", "shiloh street"]

mount_washington_keywords_filter = rates['zone'].str.contains('|'.join(mount_washington_keywords), case=False)
mtWashington = rates[mount_washington_keywords_filter]

# removing duplicates
mtWashington2 = mtWashington.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(mtWashington2)) + " zones in Mount Washington.")
print("The average rate of meters in Mount Washington is " + str(round(mtWashington2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Mount Washington is " + str(mtWashington2['meters'].sum()) + ".")



# getting brookline zones
brookline_keywords_filter = rates['zone'].str.contains("brookline", case=False)
brookline = rates[brookline_keywords_filter]

# removing duplicates
brookline2 = brookline.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(brookline2)) + " zones in Brookline.")
print("The average rate of meters in Brookline is " + str(round(brookline2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Brookline is " + str(brookline2['meters'].sum()) + ".")



# getting beechview zones
beechview_keywords_filter = rates['zone'].str.contains("beechview", case=False)
beechview = rates[beechview_keywords_filter]

# removing duplicates
beechview2 = beechview.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(beechview2)) + " zones in Beechview.")
print("The average rate of meters in Beechview is " + str(round(beechview2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Beechview is " + str(beechview2['meters'].sum()) + ".")



# getting west end zones
west_end_keywords = ["main/alexander", "west end"]

west_end_keywords_filter = rates['zone'].str.contains('|'.join(west_end_keywords), case=False)
westEnd = rates[west_end_keywords_filter]

# removing duplicates
westEnd2 = westEnd.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(westEnd2)) + " zones in West End.")
print("The average rate of meters in West End is " + str(round(westEnd2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in West End is " + str(westEnd2['meters'].sum()) + ".")



# getting East Allegheny zones
east_allegheny_keywords_filter = rates['zone'].str.contains("east ohio street lot", case=False)
eastAllegheny = rates[east_allegheny_keywords_filter]

# removing duplicates
eastAllegheny2 = eastAllegheny.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There is " + str(len(eastAllegheny2)) + " zone in East Allegheny.")
print("The average rate of meters in East Allegheny is " + str(round(eastAllegheny2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in East Allegheny is " + str(eastAllegheny2['meters'].sum()) + ".")



# getting Perry North zones
perry_north_keywords_filter = rates['zone'].str.contains("oberservatory hill lot", case=False)
perryNorth = rates[perry_north_keywords_filter]

# removing duplicates
perryNorth2 = perryNorth.drop_duplicates(subset='zone', keep='last')

# printing relevant information 
print("\n" + "There is " + str(len(perryNorth2)) + " zone in Perry North.")
print("The average rate of meters in Perry North is " + str(round(perryNorth2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Perry North is " + str(perryNorth2['meters'].sum()) + ".")



# getting downtown zones
downtown_keywords_filter = rates['zone'].str.contains("downtown", case=False)
downtown = rates[downtown_keywords_filter]

# removing duplicates
downtown2 = downtown.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(downtown2)) + " zones in Downtown.")
print("The average rate of meters in Downtown is " + str(round(downtown2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Downtown is " + str(downtown2['meters'].sum()) + ".")



# getting uptown zones
uptown_keywords_filter = rates['zone'].str.contains("uptown", case=False)
uptown = rates[uptown_keywords_filter]

# removing duplicates
uptown2 = uptown.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There are " + str(len(uptown2)) + " zones in Uptown.")
print("The average rate of meters in Uptown is " + str(round(uptown2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Uptown is " + str(uptown2['meters'].sum()) + ".")



# getting strip district zones
strip_district_keywords_filter = rates['zone'].str.contains("Strip Disctrict", case=False)
stripDist = rates[strip_district_keywords_filter]

# removing duplicates
stripDist2 = stripDist.drop_duplicates(subset='zone', keep='last')

# finding relevant information about meters in strip district
print("\n" + "There is " + str(len(stripDist2)) + " zone in Strip District.")
print("The average rate of meters in Strip District is " + str(round(stripDist2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Strip District is " + str(stripDist2['meters'].sum()) + ".")


# getting North Shore zones
north_shore_keywords = ["northside", "northshore"]

north_shore_keywords_filter = rates['zone'].str.contains('|'.join(north_shore_keywords), case=False)
northShore = rates[north_shore_keywords_filter]

# removing duplicates
northShore2 = northShore.drop_duplicates(subset='zone', keep='last')

# printing relevant information 
print("\n" + "There are " + str(len(northShore2)) + " zones in North Shore.")
print("The average rate of meters in North Shore is " + str(round(northShore2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in North Shore is " + str(northShore2['meters'].sum()) + ".")



# getting Larimer zones
larimer_keywords_filter = rates['zone'].str.contains("bakery sq", case=False)
larimer = rates[larimer_keywords_filter]

# removing duplicates
larimer2 = larimer.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There is " + str(len(larimer2)) + " zone in Larimer.")
print("The average rate of meters in Larimer is " + str(round(larimer2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Larimer is " + str(larimer2['meters'].sum()) + ".")



# getting hill district zones
hill_district_keywords = ["HILL-DIST-2", "Hill District"]

hill_district_keywords_filter = rates['zone'].str.contains('|'.join(hill_district_keywords), case=False)
hillDist = rates[hill_district_keywords_filter]

# removing duplicates
hillDist2 = hillDist.drop_duplicates(subset='zone', keep='last')

# finding relevant information about meters in hill district
print("\n" + "There are " + str(len(hillDist2)) + " zones in Hill District.")
print("The average rate of meters in Hill District is " + str(round(hillDist2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Hill District is " + str(hillDist2['meters'].sum()) + ".")



# getting monroe heights zones
monroe_heights_keywords_filter = rates['zone'].str.contains("w circ dr", case=False)
monroeHeights = rates[monroe_heights_keywords_filter]

# removing duplicates
monroeHeights2 = monroeHeights.drop_duplicates(subset='zone', keep='last')

# printing relevant information
print("\n" + "There is " + str(len(monroeHeights2)) + " zone in Monroe Heights.")
print("The average rate of meters in Monroe Heights is " + str(round(monroeHeights2['rate'].mean(), 2)) + " dollars per hour.")
print("The total amount of meters in Monroe Heights is " + str(monroeHeights2['meters'].sum()) + ".")
# Out:
# There are 5 zones in Shadyside.
# The average rate of meters in Shadyside is 1.5 dollars per hour.
# The total amount of meters in Shadyside is 165.0.
#
# There are 6 zones in Oakland.
# The average rate of meters in Oakland is 3.0 dollars per hour.
# The total amount of meters in Oakland is 184.0.
#
# There are 7 zones in East Liberty.
# The average rate of meters in East Liberty is 1.07 dollars per hour.
# The total amount of meters in East Liberty is 69.0.
#
# There are 8 zones in Squirrel Hill.
# The average rate of meters in Squirrel Hill is 1.19 dollars per hour.
# The total amount of meters in Squirrel Hill is 68.0.
#
# There is 1 zone in Homewood.
# The average rate of meters in Homewood is 1.0 dollars per hour.
# The total amount of meters in Homewood is 1.0.
#
# There are 3 zones in Bloomfield.
# The average rate of meters in Bloomfield is 1.0 dollars per hour.
# The total amount of meters in Bloomfield is 74.0.
#
# There are 3 zones in Lawrenceville.
# ...

# %%
import matplotlib.pyplot as plt

# turning above summarized rates into a dictionary
averages = {'Shadyside': 1.50, 'Oakland': 3.00, 'East Liberty': 1.07, 'Squirrel Hill': 1.19, 'Homewood': 1.00, 'Bloomfield': 1.00, 'Lawrenceville': 1.00, 'Southside Flats': 1.07, 
            'Carrick': .75, 'Allentown': 0.83, 'Mount Washington': 1.00, 'Brookline': 1.00, 'Beechview': 1.00, 'West End': 1.00, 'East Allegheny': 1.00, 'Perry North': 1.00, 'Downtown': 4.00, 
            'Uptown': 1.50, 'Strip District': 1.50, 'North Shore': 2.00, 'Larimer': 2.00, 'Hill District': 1.25, 'Monroe Heights': 1.0}
avgs_names = list(averages.keys())
avgs_values = list(averages.values())

# plotting the data
plt.rcParams["figure.figsize"] = (35,10)
plt.yticks(ticks=[0, 1, 2, 3, 4], labels=["0", "1", "2", "3", "4"])
plt.bar(range(len(averages)), avgs_values, tick_label=avgs_names, width = 0.8)
plt.bar(range(len(averages)), avgs_values, tick_label=avgs_names)
plt.grid(axis= 'y')
plt.show()

# %%
import matplotlib.pyplot as plt

# turning above summarized meter counts into a dictionary
metered_zones = {'Shadyside': 165, 'Oakland': 184, 'East Liberty': 69, 'Squirrel Hill': 68, 'Homewood': 1, 'Bloomfield': 74, 'Lawrenceville': 31, 'Southside Flats': 110, 
                'Carrick': 11, 'Allentown': 5, 'Mount Washington': 20, 'Brookline': 22, 'Beechview': 9, 'West End': 7, 'East Allegheny': 3, 'Perry North': 1, 'Downtown': 101, 
                'Uptown': 70, 'Strip District': 58, 'North Shore': 122, 'Larimer': 4, 'Hill District': 12, 'Monroe Heights': 1.0}

meter_names = list(metered_zones.keys())
meter_values = list(metered_zones.values())

# plotting the data
plt.rcParams["figure.figsize"] = (35,10)
plt.bar(range(len(metered_zones)), meter_values, tick_label=meter_names, width = 0.8)
plt.bar(range(len(metered_zones)), meter_values, tick_label=meter_names)
plt.grid(axis= 'y')
plt.show()

# %% [markdown]
# The dataset I worked with measured three important things: meter rates, meter locations, and amount of meters. I sorted the zones into neighborhoods by hand, then found all zones in a neighborhood using pandas, and finally operated on the data of the neighborhood. I mainly was looking for the amount of meters, which will be useful for measuring our combined metric, and the rates, as that is my individual metric. To do this, I took the average of the rates in the neighborhoods, and the sum of all of the meters in the neighborhood. I am personally measuring is which neighborhood has the lowest meter costs. This location would be Carrick at 75 cents per hour. However, this is only my individual metric. There are shortcomings, such as the low total meter count, which is why it will be used as part of a combined metric, rather than the sole metric.
